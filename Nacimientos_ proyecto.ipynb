# %% [markdown]
# # **IMPORTACIÓN DE LIBRERIAS **

# %%
import pandas as pd ###,manipulacion de bases de datos
import numpy as np ### operaciones aritmeticas
import seaborn as sns ## graficas estadisticas
import matplotlib.pyplot as plt ###graficas generales
import plotly.express as px ## graficas interactivas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Cargamos los datos
#nacimientos_hgeneral_medellin = pd.read_csv("/content/drive/MyDrive/dataset/nacimientos_ocurridos_hospital_general_medellin.csv")
nacimientos_hgeneral_medellin = pd.read_csv("/content/drive/MyDrive/Proyecto Bootcamp Análisis Datos/Copia de nacimientos_ocurridos_hospital_general_medellin.csv")

# %% [markdown]
# # **ANALISIS EXPLORATORIO DE DATOS **

# %%
nacimientos_hgeneral_medellin .shape
# Out:
# (6278, 32)

# %%
nacimientos_hgeneral_medellin.head()
# Out:
#     ano  periodo_de_reporte       sexo  peso_gramos  talla_centimetros  \
# 0  2022                 1.0   FEMENINO       2341.0               44.0
# 1  2022                 1.0  MASCULINO       3750.0               51.0
# 2  2022                 1.0  MASCULINO       3527.0               51.0
# 3  2022                 1.0   FEMENINO       2745.0               47.0
# 4  2022                 1.0   FEMENINO       2315.0               43.0
#
#                 fecha_nacimiento parto_atendido_por  tiempo_de_gestacion  \
# 0  2022-01-01T00:00:00.000-05:00             MEDICO                 37.0
# 1  2022-01-01T00:00:00.000-05:00             MEDICO                 40.0
# 2  2022-01-01T00:00:00.000-05:00             MEDICO                 38.0
# 3  2022-01-01T00:00:00.000-05:00             MEDICO                 38.0
# 4  2022-01-01T00:00:00.000-05:00             MEDICO                 35.0
#
#    numero_consultas_prenatales  tipo_parto  ... municipio_residencia  \
# ...

# %%
nacimientos_hgeneral_medellin.columns
# Out:
# Index(['ano', 'periodo_de_reporte', 'sexo', 'peso_gramos', 'talla_centimetros',
#        'fecha_nacimiento', 'parto_atendido_por', 'tiempo_de_gestacion',
#        'numero_consultas_prenatales', 'tipo_parto', 'multiplicidad_embarazo',
#        'apgar1', 'apgar2', 'grupo_sanguineo', 'factor_rh',
#        'pertenencia_etnica', 'edad_madre', 'estado_conyugal_madre',
#        'nivel_educativo_madre', 'ultimo_ano_aprobado_madre', 'pais_residencia',
#        'departamento_residencia', 'municipio_residencia', 'area_residencia',
#        'localidad', 'numero_hijos_nacidos_vivos', 'numero_embarazos',
#        'regimen_seguridad', 'nombre_administradora', 'edad_padre',
#        'nivel_educativo_padre', 'profesion_certificador'],
#       dtype='object')

# %%
columnas=list(nacimientos_hgeneral_medellin)

# %%
nacimientos_hgeneral_medellin_ca=nacimientos_hgeneral_medellin

# %%
#Estadistica basica
nacimientos_hgeneral_medellin_ca.describe()
# Out:
#        periodo_de_reporte  peso_gramos  talla_centimetros  \
# count         6028.000000  6027.000000        6027.000000
# mean             2.135700  2930.143023          47.473038
# std              1.155634   580.762504           3.059873
# min              1.000000   430.000000          27.000000
# 25%              1.000000  2619.500000          46.000000
# 50%              2.000000  2990.000000          48.000000
# 75%              3.000000  3313.000000          49.000000
# max              4.000000  5200.000000          55.000000
#
#        tiempo_de_gestacion  numero_consultas_prenatales       apgar1  \
# count          6025.000000                  6028.000000  6017.000000
# mean             37.857427                     6.558892     8.983048
# std               2.281214                     3.002021     1.236649
# min              24.000000                     0.000000     1.000000
# 25%              37.000000                     5.000000     9.000000
# ...

# %%
nacimientos_hgeneral_medellin_ca.head()
# Out:
#     ano  periodo_de_reporte       sexo  peso_gramos  talla_centimetros  \
# 0  2022                 1.0   FEMENINO       2341.0               44.0
# 1  2022                 1.0  MASCULINO       3750.0               51.0
# 2  2022                 1.0  MASCULINO       3527.0               51.0
# 3  2022                 1.0   FEMENINO       2745.0               47.0
# 4  2022                 1.0   FEMENINO       2315.0               43.0
#
#                 fecha_nacimiento parto_atendido_por  tiempo_de_gestacion  \
# 0  2022-01-01T00:00:00.000-05:00             MEDICO                 37.0
# 1  2022-01-01T00:00:00.000-05:00             MEDICO                 40.0
# 2  2022-01-01T00:00:00.000-05:00             MEDICO                 38.0
# 3  2022-01-01T00:00:00.000-05:00             MEDICO                 38.0
# 4  2022-01-01T00:00:00.000-05:00             MEDICO                 35.0
#
#    numero_consultas_prenatales  tipo_parto  ... municipio_residencia  \
# ...

# %%
#Verificación de datos nulos
nacimientos_hgeneral_medellin_ca.isnull()
# Out:
#         ano  periodo_de_reporte   sexo  peso_gramos  talla_centimetros  \
# 0     False               False  False        False              False
# 1     False               False  False        False              False
# 2     False               False  False        False              False
# 3     False               False  False        False              False
# 4     False               False  False        False              False
# ...     ...                 ...    ...          ...                ...
# 6273  False               False  False        False              False
# 6274  False               False  False        False              False
# 6275  False               False  False        False              False
# 6276  False               False  False        False              False
# 6277  False               False  False        False              False
#
#       fecha_nacimiento  parto_atendido_por  tiempo_de_gestacion  \
# ...

# %%
#Comprobamos la calidad de los datos
nacimientos_hgeneral_medellin_ca.isnull().sum()
# Out:
# ano                              0
# periodo_de_reporte             250
# sexo                           250
# peso_gramos                    251
# talla_centimetros              251
# fecha_nacimiento               250
# parto_atendido_por             250
# tiempo_de_gestacion            253
# numero_consultas_prenatales    250
# tipo_parto                     250
# multiplicidad_embarazo         250
# apgar1                         261
# apgar2                         261
# grupo_sanguineo                250
# factor_rh                      250
# pertenencia_etnica             250
# edad_madre                     250
# estado_conyugal_madre          250
# nivel_educativo_madre          250
# ultimo_ano_aprobado_madre      359
# pais_residencia                250
# departamento_residencia        250
# municipio_residencia           250
# area_residencia                250
# localidad                      450
# numero_hijos_nacidos_vivos     250
# numero_embarazos               250
# ...

# %%
columnas=list(nacimientos_hgeneral_medellin_ca.columns)
for i in columnas:
  print(f"esta es la columna: {i}")
  print(pd.unique(nacimientos_hgeneral_medellin_ca[i]),"\n")
# Out:
# esta es la columna: ano
# ['2022'
#  '2022,1,MASCULINO,2673,48,2022-01-03T00:00:00.000-05:00,MEDICO,37,6,ESPONTANEO,SIMPLE,9,10,B,POSITIVO,NINGUNO DE LOS ANTERIORES,23,NO ESTA CASADA Y LLEVA DOS ANOS O MAS VIVIENDO CON SU PAREJA,MEDIA ACADEMICA O CLASICA,11,COLOMBIA,ANTIOQUIA,MEDELLIN,"CENTRO POBLADO (INSPECCION, CORREGIMIENTO O CASERIO)",SIN INFORMACION,1,1,SUBSIDIADO,SAVIA SALUD E.P.S.,22,PROFESIONAL,MEDICO'
#  '2022,1,MASCULINO,2342,43,2022-01-05T00:00:00.000-05:00,MEDICO,38,7,ESPONTANEO,SIMPLE,9,10,A,POSITIVO,"NEGRO(A), MULATO(A), AFRO COLOMBIANO(A) O AFRO DESCENDIENTE",31,NO ESTA CASADA Y LLEVA MENOS DE DOS ANOS VIVIENDO CON SU PAREJA,MEDIA ACADEMICA O CLASICA,10,COLOMBIA,ANTIOQUIA,MEDELLIN,CABECERA MUNICIPAL,BUENOS AIRES,2,2,EXCEPCION,FUERZAS MILITARES,27,SIN INFORMACION,MEDICO'
# ...

# %%
# #Reemplazar valores
# nacimientos_hgeneral_medellin_ca.replace({["SAVIA SALUD E.P.S.", "SAVIA SALUD E.P.S. -CM"]:"SAVIA SALUD E.P.S",
#                                           "NUEVA EPS SA":"NUEVA EPS S.A.",
#                                           ["CAJA DE COMPENSACION FAMILIAR DEL CHOCO COMFACHOCO-CM","CAJA DE COMPENSACION FAMILIAR DEL CHOCO - COMFACHOCO -CM"]:"COMFACHOCO - CAJA DE COMPENSACION FAMILIAR DEL CHOCO",
#                                       ["SALUD  TOTAL  S.A.  E.P.S. ","SALUD TOTAL S.A.","SALUD TOTAL E.P.S. -CM"]:"SALUD TOTAL S.A",
#                                        ["ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ESS-CM", "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD EPS-S -MUTUAL SER EPS-S"," ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S. -CM",
#                                        "MUTUAL SER - ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ARS"]:"ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S."}, inplace=True)

nacimientos_hgeneral_medellin_ca.replace({
    "SAVIA SALUD E.P.S.": "SAVIA SALUD E.P.S",
    "SAVIA SALUD E.P.S. -CM": "SAVIA SALUD E.P.S",

    "NUEVA EPS SA": "NUEVA EPS S.A.",

    "CAJA DE COMPENSACION FAMILIAR DEL CHOCO COMFACHOCO-CM": "COMFACHOCO - CAJA DE COMPENSACION FAMILIAR DEL CHOCO",
    "CAJA DE COMPENSACION FAMILIAR DEL CHOCO - COMFACHOCO -CM": "COMFACHOCO - CAJA DE COMPENSACION FAMILIAR DEL CHOCO",

    "SALUD  TOTAL  S.A.  E.P.S. ": "SALUD TOTAL S.A",
    "SALUD TOTAL S.A.": "SALUD TOTAL S.A",
    "SALUD TOTAL E.P.S. -CM": "SALUD TOTAL S.A",

    "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ESS-CM": "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S.",
    "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD EPS-S -MUTUAL SER EPS-S": "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S.",
    " ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S. -CM": "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S.",
    "MUTUAL SER - ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ARS": "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S."
}, inplace=True)

# %%
#Reemplazo de datos(empresas de salud)
nacimientos_hgeneral_medellin_ca.replace(["SAVIA SALUD E.P.S.", "SAVIA SALUD E.P.S. -CM"],"SAVIA SALUD E.P.S", inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["NUEVA EPS SA","NUEVA EPS S.A. -CM"],"NUEVA EPS S.A.",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["CAJA DE COMPENSACION FAMILIAR DEL CHOCO COMFACHOCO-CM",
                                         "CAJA DE COMPENSACION FAMILIAR DEL CHOCO - COMFACHOCO -CM","CAJA DE COMPENSACION FAMILIAR DEL CHOCO - COMFACHOCO"],
                                         "COMFACHOCO - CAJA DE COMPENSACION FAMILIAR DEL CHOCO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace (["SALUD  TOTAL  S.A.  E.P.S.","SALUD TOTAL S.A.","SALUD TOTAL E.P.S. -CM","SALUD TOTAL S.A. ENTIDAD PROMOTORA DE SALUD"],"SALUD TOTAL S.A", inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ESS-CM", "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD EPS-S -MUTUAL SER EPS-S",
                                  "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S. -CM",
                                       "MUTUAL SER - ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ARS"],
                                 "ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD E.S.S.", inplace=True)
nacimientos_hgeneral_medellin_ca.replace("COOPERATIVA DE SALUD Y DESARROLLO INTEGRAL ZONA SUR ORIENTAL DE CARTAGENA LTDA. - COOSALUD E.S.S.",
                                         "COOPERATIVA DE SALUD Y DESARROLLO INTEGRAL ZONA SUR ORIENTAL DE CARTAGENA - COOSALUD -CM",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["FAMISANAR E.P.S. LTDA - CAFAM - COLSUBSIDIO -CM","FAMISANAR  LTDA. E.P.S."],"E.P.S.  FAMISANAR  LTDA.-CM",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("EPS Y MEDICINA PREPAGADA SURAMERICANA S.A -CM","EPS Y MEDICINA PREPAGADA SURAMERICANA S.A",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["CAJA DE COMPENSACION FAMILIAR\xa0 CAJACOPI ATLANTICO -CM",
                                          "CAJA DE COMPENSACION FAMILIAR\xa0 CAJACOPI ATLANTICO","CAJACOPI ATLANTICO ARS - CAJA DE COMPENSACION FAMILIAR CAJACOPI ATLANTICO ARS"],
                                         "CAJA DE DE COMPENSACION FAMILIAR  CAJACOPI ATLANTICO-CM",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["COMPENSAR   E.P.S.","COMPENSAR E.P.S. -CM"],"COMPENSAR E.P.S.",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("ASMET SALUD ESS - ASOCIACION MUTUAL LA ESPERANZA","ASMET SALUD EPS SAS",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("EMSSANAR ESS - ASOCIACION MUTUAL EMPRESA SOLIDARIA DE SALUD",
                                         "EMSSANAR S.A.S.",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("EPS SANITAS - CM","E.P.S. SANITAS",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CAJA DE COMPENSACION FAMILIAR C.C.F. DEL ORIENTE COLOMBIANO - COMFAORIENTE",
                                         "COMFAORIENTE - CAJA DE COMPENSACION FAMILIAR DEL ORIENTE COLOMBIANO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("MALLAMAS EPSI","MALLAMAS EPS INDIGENA",inplace=True)

# %%
from types import TracebackType
#Reemplazo de datos(localidad)
nacimientos_hgeneral_medellin_ca.replace("1077455984","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("AGUA FRIAS","AGUAS FRIAS",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("ALTA VISTA","ALTAVISTA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("ALEO","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("ALTO DE NIQUIA","ALTOS DE NIQUIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("AMRICA","Nan",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["ANDA LUCIA","LA ANDALUCIA"],"ANDALUCIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("ANDA LUCIA LA FRANCIA","ANDALUCIA LA FRANCIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["ARAUCALIA 2","AURACACIA 2"],"ARAUCARIAS 2",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["ARAUCARIAS","AURACARIAS","LAS ARAUCARIAS"],"ARAUCARIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("BARIO NUEVO","BARRIO NUEVO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["BARRIO 12 DE OCTUBE","BARRIO 12 DE OCTUBRE","DOCE DE OCTUBRE"],"12 DE OCTUBRE",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("BELLEN","BELEN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("BLANQUISAL","BLANQUIZAL",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("BUENOS  AIRES","BUENOS AIRES",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CABECERA MUNICIPAL","NaN",inplace=True)
nacimientos_hgeneral_medellin.replace("CALATRABA","CALATRAVA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CALAZANS","CALASANZ",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["CAMPO VALDEZ","CAMPOVALDES"],"CAMPO VALDES",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CARLO E RESTREPO","CARLOS E RESTREPO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CHAGUALUTO","EL CHAGUALO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CRISTORREY","CRISTO REY",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("DESCONOCE","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("DON MATIAS","DONMATIAS", inplace=True)
nacimientos_hgeneral_medellin_ca.replace("EL CARMEN","EL CARMEN DE VIBORAL",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("EL PICACHITO","PICAHITO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("EL PICACHO","PICACHO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["ENCESISO","ENCISO EL PINAL","ENCIZO","ENSISO","COLINAS DE ENCIZO"],"ENCISO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("FREDONA","FREDONIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("GIRARDOT","GIRARDOTA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("GIRASOL","GIRASOLES",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["JUAN 23","JUAN 23 LA QUIEBRA","JUAN VEINTITRES"],"JUAN XXIII",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["LA GABRIEL","LAS GABRIERLAS"],"LA GABRIELA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("LA ISAL","LA ISLA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("LA SO","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("LAS CAMILAS","LA CAMILA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("LLANITAS","LLANADITAS",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["MANIRQUE","MANRQUE","MANRRIQUE","MARIQUE"],"MANRIQUE",inplace=True)
nacimientos_hgeneral_medellin.replace("LA MARUCHENGA","MARUCHENGA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("MEDELIN","MEDELLIN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("MESA","LOPEZ DE MESA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("MILAGROSA","LA MILAGROSA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("MORALIA","MORAVIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("NIQIUTAO","NIQUITAO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("NO REFIERE","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("NO SABE","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("NUEVA JERUSALEM","NUEVA JERUSALEN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("OCHO DE MARZO","8 DE MARZO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("OLAYA","OLAYA HERRERA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("PABLO SEXTO","PABLO VI",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["PACHELI","PACHELY"],"PACHELLY",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("PALMAS","LAS PALMAS",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["PARQUE","PARQUE PRINCIPAL"],"NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("PLAYARICA","PLAYA RICA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["POPOLAR 1","POPULAR","POPULAR 1  LA TORRE","POPULAS","LA POPULAR","LA POPULAR 1"],
                                         "POPULAR  1",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("PLAYON","EL PLAYON",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("FREDONA","FREDONIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("LA COLINITA","LA COLINA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("LLANOS DE CIUBA","LLANOS DE CUIVA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("PUEBLO NIUEVO","PUEBLO NUEVO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("ROBEDO","ROBLEDO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("RURAL DISPERSO","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["SAN ANTONIO DE PADRO","AN ANTONIO DE PRADO"],"SAN ANTONIO DE PRADO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("SAN CRITOBAL","SAN CRISTOBAL",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("LA GERMAN","SAN GERMAN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("SAN JOSE LA CIMA","SAN JOSE DE LA CIMA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("SAN RAFALE","SAN RAFAEL",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("SANTA ROSA","SANTA ROSA DE OSOS",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("SANTACRUZ","SANTA CRUZ",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("SIN INFORMACION","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("SOL ORIENTE","SOL DE ORIENTE",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("STA RITA","SANTA RITA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["BARRIO TRAPICHE","TRAPICHE"],"EL TRAPICHE",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("TRECE DE NOVIEMBRE","13 DE NOVIEMBRE",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["VEINTE DE JULIO","VEINTE JULIO"],"20 DE JULIO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("VELLANITA","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["VILLA HEMOSA","VILLA HERMOS"],"VILLA HERMOSA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("VILLA HORIENTE","VILLA ORIENTE",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["VILLA TINA","VILLANTINA","VILLATINA LA LIBERTAD","VEREDA BILLATINA"],"VILLATINA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("VILLA DEL SOL","VILLAS DEL SOL",inplace=True)
nacimientos_hgeneral_medellin_ca.replace(["YAROMITO","YARU","YARUMITA"],"YARUMITO",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("ALTO DE NIQUIA","ALTOS DE NIQUIA",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CALLE 1","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("CALLE 59","NaN",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("DIAMANTE","EL DIAMANTE",inplace=True)
nacimientos_hgeneral_medellin_ca.replace("PEDREGAL","EL PEDREGAL",inplace=True)

# %%
columnas=list(nacimientos_hgeneral_medellin_ca.columns)
for i in columnas:
  print(f"esta es la columna: {i}")
  print(pd.unique(nacimientos_hgeneral_medellin_ca[i]),"\n")
# Out:
# esta es la columna: ano
# ['2022'
#  '2022,1,MASCULINO,2673,48,2022-01-03T00:00:00.000-05:00,MEDICO,37,6,ESPONTANEO,SIMPLE,9,10,B,POSITIVO,NINGUNO DE LOS ANTERIORES,23,NO ESTA CASADA Y LLEVA DOS ANOS O MAS VIVIENDO CON SU PAREJA,MEDIA ACADEMICA O CLASICA,11,COLOMBIA,ANTIOQUIA,MEDELLIN,"CENTRO POBLADO (INSPECCION, CORREGIMIENTO O CASERIO)",SIN INFORMACION,1,1,SUBSIDIADO,SAVIA SALUD E.P.S.,22,PROFESIONAL,MEDICO'
#  '2022,1,MASCULINO,2342,43,2022-01-05T00:00:00.000-05:00,MEDICO,38,7,ESPONTANEO,SIMPLE,9,10,A,POSITIVO,"NEGRO(A), MULATO(A), AFRO COLOMBIANO(A) O AFRO DESCENDIENTE",31,NO ESTA CASADA Y LLEVA MENOS DE DOS ANOS VIVIENDO CON SU PAREJA,MEDIA ACADEMICA O CLASICA,10,COLOMBIA,ANTIOQUIA,MEDELLIN,CABECERA MUNICIPAL,BUENOS AIRES,2,2,EXCEPCION,FUERZAS MILITARES,27,SIN INFORMACION,MEDICO'
# ...

# %%
lista_barrios = list(nacimientos_hgeneral_medellin_ca["localidad"].dropna().unique())
lista_barrios.sort()
lista_barrios
# Out:
# ['12 DE OCTUBRE',
#  '13 DE NOVIEMBRE',
#  '20 DE JULIO',
#  '8 DE MARZO',
#  'ABEJORRAL',
#  'ABRIAQUI',
#  'ACEVEDO',
#  'AGUAS FRIAS',
#  'AJIZAL',
#  'ALCALA',
#  'ALEGRIA',
#  'ALEJANDRIA',
#  'ALEJANDRO ECHAVARRIA',
#  'ALFONSO LOPEZ',
#  'ALGARROBO',
#  'ALTAMIRA',
#  'ALTAVISTA',
#  'ALTOS DE LA ESPERANZA',
#  'ALTOS DE NIQUIA',
#  'ALTOS DE ORIENTE',
#  'ANCON',
#  'ANDALUCIA',
#  'ANDALUCIA LA FRANCIA',
#  'ANDES',
#  'ANTONIO NARINO',
#  'ARANJUEZ',
#  'ARAUCARIA',
#  'ARAUCARIAS 2',
#  'ARGELIA',
#  'ARRAYANA',
#  'ASTURIAS',
#  'AURELIO MEJIA',
#  'AURES',
#  'AURORA',
#  'AURORA LA LIBERTAD',
#  'BAHIA SOLANO',
#  'BARBOSA',
#  'BARRIO ANTIOQUIA',
#  'BARRIO LA MESETA',
#  'BARRIO LA PAZ',
#  'BARRIO NUEVO',
#  'BARRIO SAN GABRIEL',
#  'BATALLON',
#  'BELALCAZAR',
#  'BELEN',
#  'BELEN AGUAS FRIAS',
#  'BELEN ALTAVISTA',
#  'BELEN LA PLAYA',
#  'BELEN RINCON',
#  'BELEN SAN BERNARDO',
#  'BELEN ZAFRA',
#  'BELENCITO',
#  'BELENCITO CORAZON',
#  'BELLA VISTA',
# ...

# %%
#Registros duplicados
nacimientos_hgeneral_medellin_ca.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Tipo de dato por columna
nacimientos_hgeneral_medellin_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6278 entries, 0 to 6277
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano                          6278 non-null   object
#  1   periodo_de_reporte           6028 non-null   float64
#  2   sexo                         6028 non-null   object
#  3   peso_gramos                  6027 non-null   float64
#  4   talla_centimetros            6027 non-null   float64
#  5   fecha_nacimiento             6028 non-null   object
#  6   parto_atendido_por           6028 non-null   object
#  7   tiempo_de_gestacion          6025 non-null   float64
#  8   numero_consultas_prenatales  6028 non-null   float64
#  9   tipo_parto                   6028 non-null   object
#  10  multiplicidad_embarazo       6028 non-null   object
#  11  apgar1                       6017 non-null   float64
# ...

# %%
#Columnas ordenadas
sorted(columnas)
# Out:
# ['ano',
#  'apgar1',
#  'apgar2',
#  'area_residencia',
#  'departamento_residencia',
#  'edad_madre',
#  'edad_padre',
#  'estado_conyugal_madre',
#  'factor_rh',
#  'fecha_nacimiento',
#  'grupo_sanguineo',
#  'localidad',
#  'multiplicidad_embarazo',
#  'municipio_residencia',
#  'nivel_educativo_madre',
#  'nivel_educativo_padre',
#  'nombre_administradora',
#  'numero_consultas_prenatales',
#  'numero_embarazos',
#  'numero_hijos_nacidos_vivos',
#  'pais_residencia',
#  'parto_atendido_por',
#  'periodo_de_reporte',
#  'pertenencia_etnica',
#  'peso_gramos',
#  'profesion_certificador',
#  'regimen_seguridad',
#  'sexo',
#  'talla_centimetros',
#  'tiempo_de_gestacion',
#  'tipo_parto',
#  'ultimo_ano_aprobado_madre']

# %%
#Filtrar un dato
nacimientos_hgeneral_medellin_ca[nacimientos_hgeneral_medellin_ca["edad_madre"]==12]
# Out:
#        ano  periodo_de_reporte      sexo  peso_gramos  talla_centimetros  \
# 3012  2022                 3.0  FEMENINO       2780.0               48.0
#
#                    fecha_nacimiento parto_atendido_por  tiempo_de_gestacion  \
# 3012  2022-08-16T00:00:00.000-05:00             MEDICO                 39.0
#
#       numero_consultas_prenatales     tipo_parto  ... municipio_residencia  \
# 3012                          3.0  INSTRUMENTADO  ...                TARSO
#
#       area_residencia    localidad numero_hijos_nacidos_vivos  \
# 3012              NaN  CALLE NUEVA                        1.0
#
#      numero_embarazos regimen_seguridad  nombre_administradora edad_padre  \
# 3012              1.0        SUBSIDIADO      SAVIA SALUD E.P.S       19.0
#
#      nivel_educativo_padre  profesion_certificador
# 3012     BASICA SECUNDARIA                  MEDICO
#
# [1 rows x 32 columns]

# %%
nacimientos_hgeneral_medellin_ca[nacimientos_hgeneral_medellin_ca["edad_padre"]==100]
# Out:
#        ano  periodo_de_reporte       sexo  peso_gramos  talla_centimetros  \
# 1346  2022                 2.0  MASCULINO       3651.0               52.0
#
#                    fecha_nacimiento parto_atendido_por  tiempo_de_gestacion  \
# 1346  2022-04-10T00:00:00.000-05:00             MEDICO                 38.0
#
#       numero_consultas_prenatales  tipo_parto  ... municipio_residencia  \
# 1346                          1.0  ESPONTANEO  ...                BELLO
#
#       area_residencia  localidad numero_hijos_nacidos_vivos numero_embarazos  \
# 1346              NaN  COMUNA 02                        2.0              2.0
#
#      regimen_seguridad  nombre_administradora edad_padre  \
# 1346        SUBSIDIADO      SAVIA SALUD E.P.S      100.0
#
#      nivel_educativo_padre  profesion_certificador
# 1346                   NaN                  MEDICO
#
# [1 rows x 32 columns]

# %%
nacimientos_hgeneral_medellin_ca[nacimientos_hgeneral_medellin_ca["edad_padre"]==100]["edad_madre"]
# Out:
# 1346    23.0
# Name: edad_madre, dtype: float64

# %%
nacimientos_hgeneral_medellin_ca[nacimientos_hgeneral_medellin_ca["edad_padre"]>80]
# Out:
#        ano  periodo_de_reporte       sexo  peso_gramos  talla_centimetros  \
# 1346  2022                 2.0  MASCULINO       3651.0               52.0
# 4327  2022                 4.0  MASCULINO       3421.0               49.0
#
#                    fecha_nacimiento parto_atendido_por  tiempo_de_gestacion  \
# 1346  2022-04-10T00:00:00.000-05:00             MEDICO                 38.0
# 4327  2022-11-15T00:00:00.000-05:00             MEDICO                 40.0
#
#       numero_consultas_prenatales     tipo_parto  ... municipio_residencia  \
# 1346                          1.0     ESPONTANEO  ...                BELLO
# 4327                         10.0  INSTRUMENTADO  ...             MEDELLIN
#
#       area_residencia  localidad numero_hijos_nacidos_vivos numero_embarazos  \
# 1346              NaN  COMUNA 02                        2.0              2.0
# 4327              NaN   CASTILLA                        4.0              5.0
#
# ...

# %%
nacimientos_hgeneral_medellin_ca[nacimientos_hgeneral_medellin_ca["edad_padre"]>80]["edad_madre"]
# Out:
# 1346    23.0
# 4327    37.0
# Name: edad_madre, dtype: float64

# %%
#Agrupamos por edad de la madre
nacimientos_hgeneral_medellin_ca.groupby("edad_madre").size()
# Out:
# edad_madre
# 12.0      1
# 13.0     14
# 14.0     30
# 15.0    112
# 16.0    150
# 17.0    240
# 18.0    304
# 19.0    397
# 20.0    411
# 21.0    401
# 22.0    392
# 23.0    373
# 24.0    334
# 25.0    319
# 26.0    292
# 27.0    293
# 28.0    278
# 29.0    238
# 30.0    213
# 31.0    173
# 32.0    165
# 33.0    164
# 34.0    135
# 35.0    109
# 36.0    109
# 37.0     84
# 38.0     69
# 39.0     78
# 40.0     60
# 41.0     31
# 42.0     26
# 43.0     15
# 44.0     11
# 45.0      3
# 46.0      2
# 47.0      2
# dtype: int64

# %%
# Visualizacion de la distribucion de las edades de las madres
plt.figure(figsize=(10,6)) # Tamaño de grafico
sns.histplot(nacimientos_hgeneral_medellin_ca["edad_madre"], bins=20, edgecolor= "k")
plt.title("Distribucion de edades de las madres") #Titulo del grafico
plt.xlabel("Edad") #Titulo ejex
plt.ylabel("Numero de madres") #Titulo ejee y
plt.grid()
plt.show() #Mostrar grafico

# %%
#Agrupamos por nivel educativo de la madre
nacimientos_hgeneral_medellin_ca.groupby("nivel_educativo_madre").size()
# Out:
# nivel_educativo_madre
# BASICA PRIMARIA               629
# BASICA SECUNDARIA            1932
# ESPECIALIZACION                 5
# MEDIA ACADEMICA O CLASICA    2510
# MEDIA TECNICA                  66
# NINGUNO                        41
# NORMALISTA                      2
# NaN                            64
# PREESCOLAR                      7
# PROFESIONAL                   239
# TECNICA PROFESIONAL           404
# TECNOLOGICA                   129
# dtype: int64

# %%
#Sexo de los nacidos vivos
nacimientos_hgeneral_medellin_ca.groupby("sexo").size()
# Out:
# sexo
# FEMENINO         2914
# INDETERMINADO       1
# MASCULINO        3113
# dtype: int64

# %%
nacimientos_hgeneral_medellin_ca.groupby("localidad").size().sort_values(ascending=False)
# Out:
# localidad
# NaN           1489
# ROBLEDO        330
# SAN JAVIER     287
# MANRIQUE       239
# COMUNA 02      232
#               ...
# LA REINA         1
# LA RONDA         1
# LA SAGRADA       1
# LA SELVA         1
# CUMBRE           1
# Length: 480, dtype: int64

# %%
#Pertenencia etnica del nacido vivo
nacimientos_hgeneral_medellin_ca.groupby("pertenencia_etnica").size()
# Out:
# pertenencia_etnica
# INDIGENA                                                       45
# NEGRO(A) MULATO(A) AFRO COLOMBIANO(A) O AFRO DESCENDIENTE      15
# NINGUNO DE LOS ANTERIORES                                    5967
# PALENQUERO DE SAN BASILIO                                       1
# dtype: int64

# %%
#Relacionamos edad de la madre y nivel educativo
nacimientos_hgeneral_medellin_ca.groupby(["edad_madre", "nivel_educativo_madre"]).size()
# Out:
# edad_madre  nivel_educativo_madre
# 12.0        BASICA PRIMARIA               1
# 13.0        BASICA PRIMARIA               9
#             BASICA SECUNDARIA             5
# 14.0        BASICA PRIMARIA              12
#             BASICA SECUNDARIA            18
#                                          ..
# 45.0        PROFESIONAL                   1
# 46.0        BASICA PRIMARIA               1
#             MEDIA ACADEMICA O CLASICA     1
# 47.0        MEDIA ACADEMICA O CLASICA     1
#             PROFESIONAL                   1
# Length: 249, dtype: int64

# %%
# Visualizacion de la distribucion de las edades de las madres
plt.figure(figsize=(12,6)) # Tamaño de grafico
sns.histplot(nacimientos_hgeneral_medellin_ca["nivel_educativo_madre"], bins=12, edgecolor= "r")
plt.title("Nivel Educativo de la Madre") #Titulo del grafico
plt.xlabel("Nivel educativo") #Titulo ejex
plt.ylabel("") #Titulo ejee y
plt.xticks(rotation=45)
plt.grid()
plt.show() #Mostrar grafico

# %%
#Relacionamos edad de la madre y numero de embarazos
df_edad_madre_numero_embarazos =nacimientos_hgeneral_medellin_ca.groupby(["edad_madre", "numero_embarazos"]).size()
df_edad_madre_numero_embarazos
# Out:
# edad_madre  numero_embarazos
# 12.0        1.0                  1
# 13.0        1.0                 13
#             2.0                  1
# 14.0        1.0                 28
#             2.0                  2
#                                 ..
# 45.0        9.0                  1
# 46.0        4.0                  1
#             6.0                  1
# 47.0        5.0                  1
#             7.0                  1
# Length: 214, dtype: int64

# %%
#Relacionamos el area de residencia con el número de embarazos
df_localidad_numeroembarazos=nacimientos_hgeneral_medellin_ca.groupby(["localidad", "numero_embarazos"]).size().sort_values(ascending=False)
df_localidad_numeroembarazos.head(20)
# Out:
# localidad      numero_embarazos
# NaN            1.0                 613
#                2.0                 431
#                3.0                 230
# ROBLEDO        1.0                 140
# SAN JAVIER     1.0                 126
# NaN            4.0                 113
# COMUNA 01      1.0                  97
# COMUNA 02      1.0                  97
# ROBLEDO        2.0                  96
# BUENOS AIRES   1.0                  89
# SANTA CRUZ     1.0                  87
# MANRIQUE       1.0                  87
# SAN JAVIER     2.0                  81
# COMUNA 02      2.0                  75
# MANRIQUE       2.0                  74
# BELEN          1.0                  73
# VILLA HERMOSA  1.0                  63
# SANTA CRUZ     2.0                  61
# COMUNA 01      2.0                  57
# NaN            5.0                  55
# dtype: int64

# %%
print(nacimientos_hgeneral_medellin_ca['ano'].dtype)
print(nacimientos_hgeneral_medellin_ca['ano'].unique())
# Out:
# object
# ['2022'
#  '2022,1,MASCULINO,2673,48,2022-01-03T00:00:00.000-05:00,MEDICO,37,6,ESPONTANEO,SIMPLE,9,10,B,POSITIVO,NINGUNO DE LOS ANTERIORES,23,NO ESTA CASADA Y LLEVA DOS ANOS O MAS VIVIENDO CON SU PAREJA,MEDIA ACADEMICA O CLASICA,11,COLOMBIA,ANTIOQUIA,MEDELLIN,"CENTRO POBLADO (INSPECCION, CORREGIMIENTO O CASERIO)",SIN INFORMACION,1,1,SUBSIDIADO,SAVIA SALUD E.P.S.,22,PROFESIONAL,MEDICO'
#  '2022,1,MASCULINO,2342,43,2022-01-05T00:00:00.000-05:00,MEDICO,38,7,ESPONTANEO,SIMPLE,9,10,A,POSITIVO,"NEGRO(A), MULATO(A), AFRO COLOMBIANO(A) O AFRO DESCENDIENTE",31,NO ESTA CASADA Y LLEVA MENOS DE DOS ANOS VIVIENDO CON SU PAREJA,MEDIA ACADEMICA O CLASICA,10,COLOMBIA,ANTIOQUIA,MEDELLIN,CABECERA MUNICIPAL,BUENOS AIRES,2,2,EXCEPCION,FUERZAS MILITARES,27,SIN INFORMACION,MEDICO'
# ...

# %%
# Visualización del número de nacimientos según el tipo de parto
plt.figure(figsize=(10,6)) # Tamaño del gráfico
sns.countplot(data=nacimientos_hgeneral_medellin_ca, x="tipo_parto", order=nacimientos_hgeneral_medellin_ca["tipo_parto"].value_counts().index) # Conteo de partos por tipo
plt.title("Cantidad de nacimientos por tipo de parto") # Título del gráfico
plt.xlabel("Tipo de parto") # Etiqueta del eje X
plt.ylabel("Cantidad de nacimientos") # Etiqueta del eje Y
plt.xticks(rotation=45) # Rotación de etiquetas del eje X para mejor lectura
plt.grid(axis="y") # Mostrar líneas de cuadrícula solo en el eje Y
plt.tight_layout() # Ajustar espaciado
plt.show() # Mostrar gráfico

# Permite ver cuál es el método de parto más común.
# Por ejemplo, si el parto espontáneo domina, es un indicador de prácticas médicas habituales o condiciones normales de embarazo.

# %%
# Visualización de la distribución de peso de los recién nacidos
plt.figure(figsize=(10,6)) # Tamaño del gráfico
sns.histplot(nacimientos_hgeneral_medellin_ca["peso_gramos"], bins=25, color='orange', edgecolor="k") # Histograma del peso
plt.title("Distribución del peso al nacer de los bebés") # Título del gráfico
plt.xlabel("Peso (gramos)") # Etiqueta del eje X
plt.ylabel("Cantidad de bebés") # Etiqueta del eje Y
plt.grid() # Mostrar líneas de cuadrícula
plt.show() # Mostrar gráfico


#permite ver cómo se distribuyen los pesos de los recién nacidos.
# identificar si la mayoría nace con un peso saludable (por ejemplo, entre 2500g y 3500g).
#También ayuda a detectar si hay muchos casos de bajo peso (menos de 2500g), lo cual es un indicador de riesgo.

# %%
# Comparación de la edad de las madres según el tipo de parto
plt.figure(figsize=(10,6)) # Tamaño del gráfico
sns.boxplot(data=nacimientos_hgeneral_medellin_ca, x="tipo_parto", y="edad_madre") # Boxplot: edad vs tipo de parto
plt.title("Edad de las madres según tipo de parto") # Título del gráfico
plt.xlabel("Tipo de parto") # Etiqueta eje X
plt.ylabel("Edad de la madre") # Etiqueta eje Y
plt.xticks(rotation=45) # Girar etiquetas para mejor lectura
plt.grid() # Mostrar cuadrícula
plt.tight_layout() # Ajustar márgenes
plt.show() # Mostrar gráfico

# permite comparar la edad de las madres entre tipos de parto.
# Puedes ver si las madres más jóvenes tienen más partos naturales, o si los partos por cesárea son más frecuentes en edades mayores.

# %%
# Conteo de nacimientos por tipo de régimen de salud
plt.figure(figsize=(10,6)) # Tamaño del gráfico
sns.countplot(data=nacimientos_hgeneral_medellin_ca, x="regimen_seguridad", order=nacimientos_hgeneral_medellin_ca["regimen_seguridad"].value_counts().index) # Conteo por régimen
plt.title("Nacimientos por régimen de seguridad en salud") # Título
plt.xlabel("Régimen de salud") # Etiqueta eje X
plt.ylabel("Cantidad de nacimientos") # Etiqueta eje Y
plt.xticks(rotation=45) # Girar etiquetas para mejor lectura
plt.grid(axis="y") # Cuadrícula en eje Y
plt.tight_layout() # Ajustar márgenes
plt.show() # Mostrar gráfico

#Permite visualizar si la mayoría de los nacimientos están registrados bajo régimen subsidiado, contributivo u otro.

# %%
# Relación entre el tiempo de gestación y el peso del bebé
plt.figure(figsize=(10,6)) # Tamaño del gráfico
sns.scatterplot(data=nacimientos_hgeneral_medellin_ca, x="tiempo_de_gestacion", y="peso_gramos", alpha=0.6, hue="sexo") # Dispersión con color por sexo
plt.title("Relación entre tiempo de gestación y peso del bebé") # Título
plt.xlabel("Semanas de gestación") # Etiqueta eje X
plt.ylabel("Peso al nacer (g)") # Etiqueta eje Y
plt.grid(True) # Cuadrícula
plt.tight_layout() # Ajustar márgenes
plt.show() # Mostrar gráfico

#muestra cómo influye la duración del embarazo en el peso del bebé.
# Por lo general, mayor tiempo de gestación → mayor peso

# %%
plt.figure(figsize=(12, 8))  # Define tamaño del gráfico
numericas = nacimientos_hgeneral_medellin_ca.select_dtypes(include="number")  # Selecciona columnas numéricas
correlacion = numericas.corr()  # Calcula matriz de correlación
mask = np.triu(np.ones_like(correlacion, dtype=bool))
sns.heatmap(correlacion, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)  # Dibuja mapa de calor con valores y colores
plt.title("Mapa de calor de correlación entre variables numéricas")  # Añade título al gráfico
plt.tight_layout()  # Ajusta diseño para evitar cortes
plt.show()  # Muestra gráfico

# %%
numericas = nacimientos_hgeneral_medellin_ca.select_dtypes(include="number")

# 2. Calcular matriz de correlación
correlacion = numericas.corr()

# 3. Crear máscara para la mitad superior (incluida la diagonal si se desea)
mask = np.triu(np.ones_like(correlacion, dtype=bool))

# 4. Configurar figura
plt.figure(figsize=(12, 8))

# 5. Dibujar heatmap con máscara y estética mejorada
sns.heatmap(
    correlacion,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    vmin=-1,
    vmax=1,
    square=True
)

# 6. Estética adicional
plt.title("Mapa de calor de correlación (mitad inferior)")
plt.tight_layout()

# 7. Mostrar gráfico
plt.show()
